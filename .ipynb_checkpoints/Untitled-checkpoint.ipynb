# %% [markdown]
# ### CREATE AGENT

# %%
import mesa 

print (" the version of mesa we are using is "+ mesa.__version__)

class MoneyAgent(mesa.Agent):
    
    def __init__(seldf, model):
        super().__init__(model)
        self.wealth = 1
# Out:
#  the version of mesa we are using is 3.4.1

# %% [markdown]
# ### CREATE MODEL

# %%
import mesa 

print (" the version of mesa we are using is "+ mesa.__version__)

class MoneyAgent(mesa.Agent):
    
    def __init__(seldf, model):
        super().__init__(model)
        self.wealth = 1
# Out:
#  the version of mesa we are using is 3.4.1

# %% [markdown]
# ###  2. ADDING AGENTS actions AND STEP METHOD

# %%
import mesa 
import matplotlib.pyplot as plt


class MoneyAgent(mesa.Agent):
    
    def __init__(seldf, model):
        super().__init__(model)
        self.wealth = 1 

    def step(self):
        print("hi , i am agent" + str(self.unique_id) + ".")

class MoneyModel(mesa.Model):
    """
    A model with some number of agents.
    This class sets up the environment and the agents within it.
    """

    def __init__(self, N):
        # Initialize the model with N agents
        super().__init__()
        self.num_agents = N  # Total number of agents in the model

        # Create agents and add them to the model
        for i in range(self.num_agents):
            a = MoneyAgent(self)  # Create a MoneyAgent associated with the model

    def step(self):
        """
        Advance the model by one step.
        Each step, every agent's 'step' method will be called.
        """
        self.agents.shuffle_do("step")  # Trigger all agents in random order to take a step
